# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmaamba/sharmaamba/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Source Code -> Compiler -> Byte Code(.pyc) -> Interpreter(PVM) -> Machine Code -> O/P

1. If there is any compile time error in source code then byte code will not be generated
2. If there is any run time error then byte code will be generated but while interpreting the code.
It will stop the execution immediately when it finds the error in the code.


# NOTE:- WHEN WE compile A PYTHON FILE(.PY) Manually _> THEN BYTE CODE(.PYC) GETS GENERATED
# IN __PYCACHE__ FOLDER IN THE SAME LOCATION WHERE .PY FILE EXISTS.

# %%
Cat - Concatenate ->
VIM -> Visual Improved

# %%
a = 10
b = 20
c = a+b
print(c)
print(a)
print(d)
print(b)

# In assignment operations -> First right hand side expression will be executed and then left hand side part will be executed
# In function call -> First function name will be resolved -> then it will se what is argument -> It will execute the argument
  # -> Argument value will be passed as input to function.

# %%
Last login: Fri Feb 25 07:59:31 on ttys000
(base) vigneshs-MacBook-Air% dc Desktop
(base) vigneshs-MacBook-Air% cd Desktop
(base) vigneshs-MacBook-Air% pwd
/Users/vigneshkarthick/Desktop
(base) vigneshs-MacBook-Air% vim f1.py
(base) vigneshs-MacBook-Air% cat f1.py
a = 10
b = 20
c = a+b
print(c)
(base) vigneshs-MacBook-Air% python f1.py
30
(base) vigneshs-MacBook-Air% python -m py_compile f1.py
(base) vigneshs-MacBook-Air% cd __pycache__
(base) vigneshs-MacBook-Air% ls
f1.cpython-38.pyc
(base) vigneshs-MacBook-Air% pwd
/Users/vigneshkarthick/Desktop/__pycache__
(base) vigneshs-MacBook-Air% python f1.cpython-38.pyc
30
(base) vigneshs-MacBook-Air% cd ..
(base) vigneshs-MacBook-Air% pwd
/Users/vigneshkarthick/Desktop


(base) vigneshs-MacBook-Air% vim f1.py
(base) vigneshs-MacBook-Air% cat f1.py
a = 10
b = 20
c = a+b
print(c)
print(a
print(b)
(base) vigneshs-MacBook-Air% python -m py_compile f1.py
  File "f1.py", line 6
    print(b)
    ^
SyntaxError: invalid syntax

(base) vigneshs-MacBook-Air% cat f1.py
a = 10
b = 20
c = a+b
print(c)
print(a)
print(d)
print(b)
(base) vigneshs-MacBook-Air% python -m py_compile f1.py
(base) vigneshs-MacBook-Air% cd __pycache__
(base) vigneshs-MacBook-Air% python f1.cpython-38.pyc
30
10
Traceback (most recent call last):
  File "f1.py", line 6, in <module>
NameError: name 'd' is not defined
(base) vigneshs-MacBook-Air%


(base) vigneshs-MacBook-Air% cd ..
(base) vigneshs-MacBook-Air% pwd
/Users/vigneshkarthick/Desktop
(base) vigneshs-MacBook-Air% python -m dis f1.py
  1           0 LOAD_CONST               0 (10)
              2 STORE_NAME               0 (a)

  2           4 LOAD_CONST               1 (20)
              6 STORE_NAME               1 (b)

  3           8 LOAD_NAME                0 (a)
             10 LOAD_NAME                1 (b)
             12 BINARY_ADD
             14 STORE_NAME               2 (c)

  4          16 LOAD_NAME                3 (print)
             18 LOAD_NAME                2 (c)
             20 CALL_FUNCTION            1
             22 POP_TOP

  5          24 LOAD_NAME                3 (print)
             26 LOAD_NAME                0 (a)
             28 CALL_FUNCTION            1
             30 POP_TOP

  6          32 LOAD_NAME                3 (print)
             34 LOAD_NAME                4 (d)
             36 CALL_FUNCTION            1
             38 POP_TOP

  7          40 LOAD_NAME                3 (print)
             42 LOAD_NAME                1 (b)
             44 CALL_FUNCTION            1
             46 POP_TOP
             48 LOAD_CONST               2 (None)
             50 RETURN_VALUE

# %%
python -m dis my_file1.py


 0           RESUME                   0

  1           LOAD_CONST               0 (10)
              STORE_NAME               0 (a)

  2           LOAD_CONST               1 (20)
              STORE_NAME               1 (b)

  3           LOAD_NAME                0 (a)
              LOAD_NAME                1 (b)
              BINARY_OP                0 (+)
              STORE_NAME               2 (c)

  4           LOAD_NAME                3 (print)
              PUSH_NULL
              LOAD_NAME                2 (c)
              CALL                     1
              POP_TOP

  5           LOAD_NAME                3 (print)
              PUSH_NULL
              LOAD_NAME                0 (a)
              CALL                     1
              POP_TOP

  6           LOAD_NAME                3 (print)
              PUSH_NULL
              LOAD_NAME                4 (d)
              CALL                     1
              POP_TOP

  7           LOAD_NAME                3 (print)
              PUSH_NULL
              LOAD_NAME                1 (b)
              CALL                     1
              POP_TOP
              RETURN_CONST             2 (None)

# %%
# Python Features

1. Python is simple, Easy to understand and Expressive Language.
2. Python is Free(No License is required to use Python) and Open Source(Source code of python is available freely.)
3. Python is Portable(Source code) and Platform indepnendent(Byte code) both.
4. Python is Interpreted Language.
5. Pythin is Dynamically Typed Language.
6. Python supports almost all the paradigm:-
  1. Scripting Programming Paradigm
  2. Procedural Programming Paradigm
  3. Functional Programming Paradigm
  4. Modular Programming Paradigm - module - .py
  5. Object Oriented Programming Paradigm - class, object

7. Python has huge library support and community support.
8. Python comes with batteries included.

# %%
# Statically Tyoed Language - C, Java, C++ etc - SPecify the data type of variable at the time of declaration
# Dynamically Typed - Python, JS etc - No need to specify tge data type at the time of decalartion

# %%
a = 10
b = 20
c = a+b
print(c)
print(a, type(a))
a = 10.20
print(a, type(a))
a = "10"
print(a, type(a))
print(b)
# Out:
# 30
# 10 <class 'int'>
# 10.2 <class 'float'>
# 10 <class 'str'>
# 20

# %%
# Scripting - Follow the basic Programming constructs in Python
# Basic concepts, if,elif, else, loop data strcuture in python etc


# Procedural -> You are going to use procedures/User defined functions,
# You as a developer have to take care pof the steps your program is going to follow to achieveb a task
# def

# Functional Programmong - We use Builtin function and methods to get the job done
# and we don't bother much about how it is implementing it internaly.

# %%
# Printing the larger number out of two numbers
# Scripting
a = 10
b = 20
if a<b:
  print('a is less than b')
else:
  print('a is greater than b')
# Out:
# a is less than b

# %%
# Procedural - Procedure - User defined function
a = 10
b = 20
def large_num(num1, num2):
  if num1>num2:
    print(f'{num1} is greater')
  else:
    print(f'{num2} is greater')
large_num(a,b)
# Out:
# 20 is greater

# %%
# Functional Programming
a = 10
b = 20
print(max(a, b))


# lambda, map, filter
# Out:
# 20

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...
